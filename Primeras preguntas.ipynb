# %% [markdown]
# # Exportacion e importacion de FOB, CIF, Bultos y Peso por mes y oño

# %%
import pandas as pd
import matplotlib.pyplot as plt
import os
import csv
import seaborn as sns

# %% [markdown]
# ### ¿Cuanto importamos de todo (FOB, CIF, CANT_BUL1 ) por mes (enero a diciembre)?

# %%
filename = "data" + os.sep + "import" + os.sep + "all_import_with_group.txt"
usecols =  ["YEAR", "MONTH", "FOB", "CIF", "CANT_BUL1"]

data = pd.read_csv(filename, decimal=',',
                   sep=";", encoding="latin1", quoting=csv.QUOTE_NONE,
                   usecols = usecols)
 

for element,text in [("FOB",  "Valor FOB"),
                     ("CIF", "Valor CIF"),
                     ("CANT_BUL1", "Cantidad de Bultos 1")]:
    
    # Month
    
    new_data = data[["YEAR", "MONTH", element]]
    new_data_grouper = new_data.groupby(['MONTH','YEAR']).sum()

    plot = new_data_grouper.unstack().plot(kind='bar',stacked=True,figsize=(15, 10))

    plot.set_title(text + " agrupado por año y mes")
    plot.set_xlabel("Meses")
    plot.set_ylabel(text)
    plot.legend(["2011","2012","2013","2014", "2015", "2016", "2017"], loc=9,ncol=7)

    plt.show()
    print(new_data_grouper.unstack().to_string())
# Out:
#               FOB
# YEAR         2011        2012        2013        2014        2015        2016        2017
# MONTH
# 1      4888064.52  4353771.09  6056777.17  7593420.97  6435721.54  5818110.82  6896279.64
# 2      3450575.52  5703834.57  4767096.52  5537482.79  8176762.76  5772075.39  6507211.18
# 3      3911041.20  4685263.50  3343083.91  7750286.29  5394308.64  5111160.93  6822647.56
# 4      2690670.68  3639448.90  4745804.12  7172800.94  7836499.29  8119641.77  5587168.40
# 5      3697685.28  5701992.48  6404855.68  4969624.94  4777626.95  5844976.14  9149954.24
# 6      2561076.61  3541822.71  4640203.94  6730891.89  5580839.37  4419497.19         NaN
# 7      3247977.19  4042974.55  5890539.64  7138703.79  7247801.56  6030621.24         NaN
# 8      3854440.07  5809325.56  5969979.44  5024861.50  5762165.54  6965501.99         NaN
# 9      3934698.18  3689028.43  5278466.32  5553602.75  5599090.04  6214556.10         NaN
# 10     4542071.59  6657835.17  6406582.16  6744706.33  6263828.76  6740190.36         NaN
# 11     3314151.24  6612511.47  5349239.33  4744193.82  5051211.49  6259223.26         NaN
# 12     3507323.59  3874047.33  4847661.65  7159570.05  5599878.64  5548757.84         NaN
#               CIF
# YEAR         2011        2012        2013        2014        2015        2016         2017
# MONTH
# 1      5788826.23  5390142.53  7425242.24  9086683.71  7446918.24  6682989.51   7906739.88
# 2      4258901.06  7023524.47  6151110.28  6889484.24  9367644.79  6822076.78   7599280.72
# 3      5002774.74  5853021.06  4487453.87  9338368.71  6442432.00  6316859.95   7971047.63
# 4      3527406.52  4657493.18  6442853.00  8465647.26  9137682.21  9399125.26   6573287.11
# 5      4849164.79  7334784.70  8166651.89  6298692.18  5856676.69  7089862.08  10760985.12
# 6      3334255.05  4589594.77  5937640.67  7892044.24  6668873.34  5297046.20          NaN
# 7      4409952.99  5463302.99  7711901.70  8443542.90  8456135.51  7185575.28          NaN
# 8      5193046.69  7447225.82  7553920.69  6089394.61  6811595.54  8277305.19          NaN
# 9      4999181.88  4907330.60  6584974.58  6855663.63  6647981.30  7427199.22          NaN
# 10     5930777.57  8684726.66  8059574.88  8135478.22  7528820.45  7969281.56          NaN
# 11     4392551.12  8335881.56  6647939.72  5753182.87  6092934.89  7375218.19          NaN
# 12     4612110.06  5113238.11  6071926.29  8429091.45  6662266.27  6686685.19          NaN
#       CANT_BUL1
# YEAR       2011     2012     2013     2014     2015     2016     2017
# MONTH
# 1       16320.0  14686.0  23087.0  33507.0  22815.0  15766.0  25712.0
# 2       18209.0  22949.0  26909.0  37014.0  24346.0  21530.0  25824.0
# 3       22912.0  23923.0  30293.0  46770.0  32083.0  37127.0  30071.0
# 4       16247.0  19517.0  44604.0  25993.0  29927.0  25747.0  27854.0
# 5       27814.0  34508.0  40764.0  43291.0  29998.0  36498.0  49239.0
# 6       17102.0  20416.0  31104.0  27139.0  26510.0  21916.0      NaN
# 7       24776.0  34802.0  53779.0  34519.0  25938.0  30067.0      NaN
# 8       31544.0  30946.0  51450.0  30988.0  28184.0  33666.0      NaN
# 9       21750.0  28242.0  40079.0  34324.0  25931.0  34229.0      NaN
# 10      30238.0  49404.0  55785.0  43703.0  32194.0  36306.0      NaN
# 11      23379.0  31284.0  36760.0  29468.0  25314.0  29635.0      NaN
# 12      22453.0  28817.0  34945.0  34638.0  27335.0  31641.0      NaN

# %% [markdown]
# ### ¿Cuanto exportamos de todo (TOTALBULTOS, PESOBRUTOTOTAL, TOTALVALORFOB) por mes (enero a diciembre)?

# %%
filename = "data" + os.sep + "export" + os.sep + "all_export_with_group.txt"
usecols =  ["YEAR", "MONTH", "TOTALBULTOS", "PESOBRUTOTOTAL", "TOTALVALORFOB"]

data = pd.read_csv(filename, decimal=',',
                   sep=";", encoding="latin1", quoting=csv.QUOTE_NONE,
                   usecols = usecols)
 

for element,text in [("TOTALBULTOS",  "Cantidad de Bultos"),
                     ("PESOBRUTOTOTAL", "Pesos Bruto Total"),
                     ("TOTALVALORFOB", "Valor FOB Total")]:
    # Month
    
    new_data = data[["YEAR", "MONTH", element]]
    new_data_grouper = new_data.groupby(['MONTH','YEAR']).sum()

    plot = new_data_grouper.unstack().plot(kind='bar',stacked=True,figsize=(15, 10))

    plot.set_title(text + " agrupado por año y mes")
    plot.set_xlabel("Meses")
    plot.set_ylabel(text)
    plot.legend(["2011","2012","2013","2014", "2015", "2016", "2017"], loc=9,ncol=7)

    plt.show()
    print(new_data_grouper.unstack().to_string())
# Out:
#       TOTALBULTOS
# YEAR         2011     2012     2013     2014     2015     2016     2017
# MONTH
# 1         11814.0  20144.0  40831.0  35873.0  26504.0  23262.0  19081.0
# 2         19899.0   5496.0  13537.0  15069.0  15474.0  24127.0    112.0
# 3         21280.0  12575.0  14088.0  13803.0   5732.0   3516.0  27999.0
# 4          7910.0   7601.0   1911.0   1165.0  20612.0  32188.0   7589.0
# 5          8519.0   8861.0   7470.0   8406.0   5714.0   4694.0   7589.0
filename_export = "data" + os.sep + "import" + os.sep + "all_import_with_group.txt"

usecols_import =  ["YEAR", "TOTALBULTOS", "PESOBRUTOTOTAL", "TOTALVALORFOB", "VALORCIF"]
usecols_export =  ["YEAR", "FOB", "CIF", "CANT_BUL1", "TOT_PESO"]

data_import = pd.read_csv(filename_import, decimal=',',
                   sep=";", encoding="latin1", quoting=csv.QUOTE_NONE,
                   usecols = usecols_import)

data_export = pd.read_csv(filename_export, decimal=',',
                          sep=";", encoding="latin1", quoting=csv.QUOTE_NONE,
                          usecols = usecols_export)
# concatenate data

data_import["TYPE"] = "Import"
data_export["TYPE"] = "Export"

data_import.columns = ['BULTOS', 'PESO', 'FOB', 'CIF', 'YEAR', 'TYPE']

data_export.columns = ['FOB', 'PESO', 'CIF', 'BULTOS', 'YEAR', 'TYPE']

final_data = pd.concat([data_import, data_export])

for element, text in [("BULTOS", "Cantidad de Bultos"),
                      ("PESO"  , "Pesos Bruto Total" ),
                      ("FOB"   , "Valor FOB Total"   ),
                      ("CIF"   , "Valor CIF"         )]:

    
    new_data = final_data[["YEAR", "TYPE", element]]
    new_data_grouper = new_data.groupby(["YEAR", 'TYPE']).sum()

    plot = new_data_grouper.unstack().plot(kind='bar',figsize=(15, 10))

    plot.set_title("Exportacion e importacion de " + text + " agrupado por año")
    plot.set_xlabel("Años")
    plot.set_ylabel(text)
    
    plot.legend(["Export","Import"], loc=9,ncol=7)
    
    plt.show()
    print(new_data_grouper.unstack().to_string())
# Out:
#       BULTOS
# TYPE  Export  Import
# YEAR
# 2011  272744  188346
# 2012  339494  178525
# 2013  469559  205771
# 2014  421354  287442
# 2015  330575  346058
# 2016  354128  377921
# 2017  158700   62370
#              PESO
# TYPE       Export       Import
# YEAR
# 2011  16794463.76  25791005.12
# 2012  20652094.17  21849228.26
# 2013  21481549.16  21424588.64
# 2014  26178000.92  18810986.01
# 2015  26543725.79  15923014.51
# 2016  30147534.34  15605381.99
# 2017  15786260.48   1648350.18
#                FOB
# TYPE        Export       Import
# YEAR
# 2011  4.359978e+07  87902763.20
# 2012  5.831186e+07  63489772.60
# 2013  6.370029e+07  59059207.23
# 2014  7.612015e+07  61312003.60
# 2015  7.372573e+07  49745925.77
# 2016  7.284431e+07  53984026.11
# 2017  3.496326e+07   8016879.67
#               CIF
# TYPE       Export       Import
# YEAR
# 2011  56298948.70   8987784.92
# 2012  74800266.45  10351256.05
# 2013  81241189.81  11238537.72
# 2014  91677274.02  23237790.89
# 2015  87119961.23  24198242.43
# 2016  86529224.41  23128424.36
# 2017  40811340.46   3948480.56

# %% [markdown]
# ### ¿Cuanto importamos de A, B, C, D y E (de cada grupo FOB, CIF, CANT_BUL1) por mes (enero a diciembre)?

# %%
filename = "data" + os.sep + "import" + os.sep + "all_import_with_group.txt"
usecols =  ["YEAR", "MONTH", "FOB", "CIF", "CANT_BUL1", "GROUP"]

data = pd.read_csv(filename, decimal=',',
                   sep=";", encoding="latin1", quoting=csv.QUOTE_NONE,
                   usecols = usecols)
 

for element,text in [("FOB",  "Valor FOB"),
                     ("CIF", "Valor CIF"),
                     ("CANT_BUL1", "Cantidad de Bultos 1")]:
    # Month
    
    fig, axes_month_share_y = plt.subplots(5, sharex=True, sharey=True)
    fig, axes_month = plt.subplots(5, sharex=True)

    i = 0
    
    tables = []
    
    for group in ["A", "B", "C", "D", "E"]:
        
        new_data = data[["YEAR", "MONTH", "GROUP", element]]
        new_data = new_data[new_data["GROUP"] == group]
        
        new_data_grouper = new_data.groupby(['MONTH','YEAR']).sum()

        plot = new_data_grouper.unstack().plot(kind='bar',
                                               ax=axes_month_share_y[i],
                                               stacked=True,
                                               figsize=(15, 20))

        plot.set_title(text + " grupo " + group + " por año y mes. Comparten Eje y")
        plot.set_xlabel("Meses")
        plot.set_ylabel(text)
        

        plot.legend(["2011","2012","2013","2014", "2015", "2016", "2017"],
                     loc='center left', bbox_to_anchor=(1.0, 0.5))
        
        plot = new_data_grouper.unstack().plot(kind='bar',
                                               ax=axes_month[i],
                                               stacked=True,
                                               figsize=(15, 20))

        plot.set_title(text + " grupo " + group + " por año y mes")
        plot.set_xlabel("Meses")
        plot.set_ylabel(text)
        

        plot.legend(["2011","2012","2013","2014", "2015", "2016", "2017"],
                     loc='center left', bbox_to_anchor=(1.0, 0.5))
        
        i += 1
        
        tables.append(new_data_grouper.unstack().to_string())
        
    plt.show()
    
    for table, group in zip(tables, ["A", "B", "C", "D", "E"]):
        print("----- {} del grupo {} ------\n\n{}\n".format(text, group, table))
# Out:
# ----- Valor FOB del grupo A ------
#
#               FOB
# YEAR         2011        2012        2013        2014        2015        2016        2017
# MONTH
# 1      3788916.57  1679208.51  2807393.45  2942646.71  2699949.62  2336248.05  3421637.99
# 2      2058509.54  2165443.14  1667329.69  1801379.71  2778893.36  1519164.39  2152828.53
# 3      2284781.65  1667453.22   862736.50  3668023.88  1713232.51   917408.09  2362549.93
# 4       904995.82   575392.42   735908.98  2242917.44  1385293.39  2520285.14  1692921.28
# 5      1613874.69  1667000.83  2366811.69  1187937.90  1462795.49  1448695.97  2422877.84
# 6       870743.95   538602.39  1608818.44  1648144.65  1301379.88   798477.27         NaN
# 7       889568.08   330055.73   694285.48  1547420.51  1112758.30  1692204.48         NaN
# 8      1205073.00  1170286.96   539439.83   682972.97  1662705.32  1182159.20         NaN
# 9      1039416.10   833858.44   947787.74   809205.02   551742.75  1710255.25         NaN
# 10      762842.44  1080583.57   425256.61   386455.51   796507.51  1483848.97         NaN
# 11      972115.26   904671.22   893532.27   342636.61  1094770.95  1384696.88         NaN
# 12      918887.21   857358.70   671277.71  1403439.74  1645894.82  1347712.95         NaN
#
# ----- Valor FOB del grupo B ------
#
#              FOB
# YEAR        2011       2012       2013       2014       2015       2016       2017
# MONTH
# 1      155109.12  216067.72  416457.44  163088.43   67233.45  264618.00  171956.29
# 2       58838.90  575470.83  172066.23  585742.58   88493.26  213222.28  190083.21
# 3      151772.45  245911.13  117733.64  125439.10   26799.62  111105.41   76745.63
# YEAR       2011   2012   2013   2014   2015   2016   2017
# MONTH
# 1         253.0  464.0  753.0  318.0  119.0  105.0  111.0
# 2         390.0  184.0   67.0  355.0  572.0   74.0   87.0
# 3         726.0  141.0   65.0   74.0   41.0  214.0   83.0
# 4         372.0  101.0   31.0  209.0   37.0   81.0   43.0
# 5         177.0   49.0   67.0   34.0   38.0   93.0   60.0
# 6         281.0  251.0  585.0  322.0   47.0   36.0    NaN
# 7         501.0   23.0   29.0   62.0   38.0   39.0    NaN
# 8         430.0  546.0  394.0  742.0  388.0   51.0    NaN
# 9         130.0  128.0   26.0   47.0  200.0   79.0    NaN
# 10         21.0   41.0   46.0  104.0   53.0  110.0    NaN
# 11        386.0   35.0   27.0   23.0   52.0   38.0    NaN
# 12         25.0   23.0   19.0   94.0   70.0  141.0    NaN
#
# ----- Cantidad de Bultos 1 del grupo B ------
#
#       CANT_BUL1
# YEAR       2011   2012    2013   2014   2015   2016   2017
# MONTH
# 1         614.0  126.0   964.0  851.0  868.0   59.0  438.0
# 2         718.0  271.0   333.0  565.0  151.0  266.0  388.0
# 3         747.0  233.0   870.0  200.0  215.0    9.0  203.0
# 4          93.0  231.0   299.0  345.0  303.0  123.0   33.0
# 5         331.0  360.0   136.0   48.0   37.0  194.0  194.0
# 6         129.0   56.0    15.0  144.0  270.0   63.0    NaN
# 7         163.0   90.0   356.0  353.0   66.0  162.0    NaN
# 8        1511.0  428.0   219.0  177.0  824.0  508.0    NaN
# 9        1129.0  164.0   764.0  442.0  329.0  317.0    NaN
# 10       1244.0  492.0   321.0  756.0  404.0  180.0    NaN
# 11       1407.0  522.0  1191.0  378.0  847.0  155.0    NaN
# 12        918.0  363.0   619.0  595.0  821.0  239.0    NaN
#
# ----- Cantidad de Bultos 1 del grupo C ------
#
#       CANT_BUL1
# YEAR       2012   2013   2014   2015    2016   2017
# MONTH
# 1          22.0   16.0  263.0   16.0    18.0  105.0
# 2          31.0    9.0    7.0   35.0    14.0   11.0
# 3          90.0   98.0    5.0    9.0   169.0   53.0
# 4          16.0   66.0   89.0   14.0   161.0   94.0
# 5          21.0    4.0   30.0   10.0  1077.0   15.0
# 6          86.0    3.0   11.0   25.0    13.0    NaN
# 7           8.0  424.0   90.0   10.0     9.0    NaN
# 8         429.0   34.0  195.0   19.0   141.0    NaN
# 9         105.0   50.0    8.0  138.0   354.0    NaN
# 10        232.0  161.0  573.0    5.0    81.0    NaN
# 11        358.0  308.0   18.0  261.0   315.0    NaN
# 12         52.0   25.0  293.0    7.0   692.0    NaN
#
# ----- Cantidad de Bultos 1 del grupo D ------
#
#       CANT_BUL1
# YEAR       2011     2012     2013     2014     2015     2016     2017
# MONTH
# 1       15453.0  14060.0  21340.0  32065.0  21651.0  15480.0  25055.0
# 2       17101.0  22438.0  26494.0  35809.0  23584.0  20938.0  25233.0
# 3       21439.0  23295.0  29248.0  46491.0  31488.0  36006.0  29587.0
# 4       15782.0  19162.0  44205.0  25314.0  29566.0  25381.0  27679.0
# 5       27306.0  34063.0  40544.0  43178.0  29910.0  34923.0  48684.0
# 6       16692.0  20014.0  30466.0  26659.0  26168.0  21804.0      NaN
# 7       24112.0  34663.0  52965.0  34013.0  25822.0  29720.0      NaN
# 8       29603.0  29531.0  50791.0  29870.0  26815.0  32807.0      NaN
# 9       20491.0  27833.0  39196.0  33783.0  25134.0  33226.0      NaN
# 10      28973.0  48458.0  55246.0  42234.0  31731.0  35929.0      NaN
# 11      21586.0  30295.0  35224.0  29039.0  24152.0  29124.0      NaN
# 12      21510.0  28378.0  34278.0  33636.0  26190.0  30484.0      NaN
#
# ----- Cantidad de Bultos 1 del grupo E ------
#
#       CANT_BUL1
# YEAR       2012  2013   2014   2015   2016   2017
# MONTH
# 1          14.0  14.0   10.0  161.0  104.0    3.0
# 2          25.0   6.0  278.0    4.0  238.0  105.0
# 3         164.0  12.0    NaN  330.0  729.0  145.0
# 4           7.0   3.0   36.0    7.0    1.0    5.0
# 5          15.0  13.0    1.0    3.0  211.0  286.0
# 6           9.0  35.0    3.0    NaN    NaN    NaN
# 7          18.0   5.0    1.0    2.0  137.0    NaN
# 8          12.0  12.0    4.0  138.0  159.0    NaN
# 9          12.0  43.0   44.0  130.0  253.0    NaN
# 10        181.0  11.0   36.0    1.0    6.0    NaN
# 11         74.0  10.0   10.0    2.0    3.0    NaN
# 12          1.0   4.0   20.0  247.0   85.0    NaN

# %% [markdown]
# ### ¿Cuanto exportamos de A,B,C,D y E (de cada grupo TOTALBULTOS, PESOBRUTOTOTAL, TOTALVALORFOB) por mes (enero a diciembre)?

# %%
filename = "data" + os.sep + "export" + os.sep + "all_export_with_group.txt"
usecols =  ["YEAR","MONTH", "TOTALBULTOS", "PESOBRUTOTOTAL", "TOTALVALORFOB", "GROUP"]

data = pd.read_csv(filename, decimal=',',
                   sep=";", encoding="latin1", quoting=csv.QUOTE_NONE,
                   usecols = usecols)
 
for element,text in [("TOTALBULTOS",  "Cantidad de Bultos"),
                     ("PESOBRUTOTOTAL", "Pesos Bruto Total"),
                     ("TOTALVALORFOB", "Valor FOB Total")]:
    
    fig, axes_month_share_y = plt.subplots(5, sharex=True, sharey=True)
    fig, axes_month = plt.subplots(5, sharex=True)

    i = 0
    
    tables = []
    
    for group in ["A", "B", "C", "D", "E"]:
        
        new_data = data[["YEAR","MONTH", "GROUP", element]]
        new_data = new_data[new_data["GROUP"] == group]
        
        new_data_grouper = new_data.groupby(["MONTH", 'YEAR']).sum()

        plot = new_data_grouper.unstack().plot(kind='bar',
                                               ax=axes_month_share_y[i],
                                               stacked=True,
                                               figsize=(15, 20))

        plot.set_title(text + " grupo " + group + " por año y mes. Comparten Eje y")
        plot.set_xlabel("Meses")
        plot.set_ylabel(text)
        
        plot.legend(["2011","2012","2013","2014", "2015", "2016", "2017"],
                     loc='center left', bbox_to_anchor=(1.0, 0.5))
        

        
        plot = new_data_grouper.unstack().plot(kind='bar',
                                               ax=axes_month[i],
                                               stacked=True,
                                               figsize=(15, 20))

        plot.set_title(text + " grupo " + group + " por año y mes")
        plot.set_xlabel("Meses")
        plot.set_ylabel(text)
        
        plot.legend(["2011","2012","2013","2014", "2015", "2016", "2017"],
                     loc='center left', bbox_to_anchor=(1.0, 0.5))
        
        i += 1
        
        tables.append(new_data_grouper.unstack().to_string())
        
    plt.show()
    
    for table, group in zip(tables, ["A", "B", "C", "D", "E"]):
        print("----- {} del grupo {} ------\n\n{}\n".format(text, group, table))
# Out:
# ----- Cantidad de Bultos del grupo A ------
#
#       TOTALBULTOS
# YEAR         2011   2012   2013   2014   2015   2016   2017
# MONTH
# 1            27.0  300.0   93.0   61.0  110.0   73.0  110.0
# 2           305.0  178.0  129.0    1.0  207.0   66.0  111.0
# 3            64.0  176.0   37.0  255.0  244.0  146.0  235.0
# 4           283.0  537.0  370.0  396.0   15.0  396.0   35.0
# 5            69.0   34.0   23.0   81.0  130.0   80.0   35.0
# 6           196.0   51.0   94.0  102.0   79.0   83.0    NaN
# 7            66.0   10.0   23.0   79.0   66.0  107.0    NaN
# 8           363.0  137.0  196.0  164.0   58.0  100.0    NaN
# 9           415.0  379.0  433.0  221.0  171.0  187.0    NaN
# 10         1408.0  570.0  488.0  354.0  319.0  257.0    NaN
# 11          177.0  305.0   84.0  151.0  157.0  118.0    NaN
# 12          130.0   84.0   24.0   20.0   78.0   99.0    NaN
#
# ----- Cantidad de Bultos del grupo B ------
#
#       TOTALBULTOS
# YEAR         2011  2012  2013  2014  2015  2016
# MONTH
# 1           102.0   NaN   NaN   NaN   NaN   NaN
# 2          1184.0   NaN   NaN   NaN   NaN   NaN
# 3           177.0   NaN   NaN   NaN   NaN   4.0
# 4           787.0   1.0   NaN   NaN   NaN   NaN
# 5           998.0   NaN  10.0   5.0   NaN   6.0
# 6           437.0  69.0  32.0  27.0  30.0  36.0
# 7           277.0   6.0  20.0   NaN   1.0   NaN
# 8            58.0   4.0   1.0   NaN   NaN   NaN
# 9           340.0   NaN   NaN   NaN   NaN   NaN
# 10          439.0   NaN   NaN   NaN   NaN   NaN
# 11           39.0   NaN   NaN   NaN   NaN   NaN
# 12           10.0   NaN   NaN   NaN   NaN   NaN
#
# ----- Cantidad de Bultos del grupo C ------
#
#       TOTALBULTOS
# YEAR         2012   2013   2014   2015   2016  2017
# MONTH
# 1             4.0    NaN  112.0    NaN    NaN   8.0
# 2           104.0  454.0  128.0    7.0    NaN   NaN
# 3           910.0    NaN  152.0    1.0    NaN   6.0
# 4           275.0  444.0   38.0  175.0    5.0  89.0
# 5           178.0  348.0  695.0  328.0    8.0  89.0
# 6           331.0  137.0  312.0  258.0  120.0   NaN
# 7           138.0  159.0  122.0    2.0   67.0   NaN
# 8             NaN    NaN    3.0    NaN  558.0   NaN
# 9             1.0    NaN   43.0   51.0  275.0   NaN
# 10          120.0   56.0   46.0    NaN  107.0   NaN
# 11            NaN    NaN    NaN    NaN  177.0   NaN
# 12          204.0    NaN    NaN    1.0   25.0   NaN
# 12        1002568.00   593443.2   419132.00   331472.30   744075.70  1135426.50        NaN
#
# ----- Pesos Bruto Total del grupo B ------
#
#       PESOBRUTOTOTAL
# YEAR            2011     2012      2013    2014      2015     2016
# MONTH
# 1             804.00      NaN       NaN     NaN       NaN      NaN
# 2           98384.76      NaN       NaN     NaN       NaN      NaN
# 3           29173.66      NaN       NaN     NaN       NaN  74000.0
# 4          275761.72  16500.0       NaN     NaN       NaN      NaN
# 5          678690.04      NaN     374.0   192.0       NaN    276.0
# 6          419211.02   2600.0    1168.0  1143.0  268336.0   1302.0
# 7          150402.56     37.0  396000.0     NaN      14.0      NaN
# 8           12164.40    140.0    5600.0     NaN       NaN      NaN
# 9          105453.15      NaN       NaN     NaN       NaN      NaN
# 10           6832.50      NaN       NaN     NaN       NaN      NaN
# 11            301.00      NaN       NaN     NaN       NaN      NaN
# 12         118476.00      NaN       NaN     NaN       NaN      NaN
#
# ----- Pesos Bruto Total del grupo C ------
#
#       PESOBRUTOTOTAL
# YEAR            2012     2013     2014      2015     2016     2017
# MONTH
# 1             327.00      NaN   865.84       NaN      NaN  54735.0
# 2             815.00  3438.04   988.24     83.00      NaN      NaN
# 3            7307.00      NaN  1468.66   7420.00      NaN    270.0
# 4            2173.38  3879.95  7621.40   1316.96    417.0    969.0
# 5            1404.00  3575.54  5295.31   2539.88    268.0    969.0
# 6            6754.15  7996.00  2351.62   1958.00   2439.0      NaN
# 7            1038.24  1288.75   941.44  38000.00  51209.0      NaN
# 8                NaN      NaN  4262.00       NaN  41666.8      NaN
# 9              79.00      NaN   337.68    378.00  21301.1      NaN
# 10            913.00   423.80   419.30       NaN   1418.0      NaN
# 11               NaN      NaN      NaN       NaN   1350.0      NaN
# 12           1636.00      NaN      NaN     78.00  67240.0      NaN
#
# ----- Pesos Bruto Total del grupo D ------
#
#       PESOBRUTOTOTAL
# YEAR            2011       2012       2013       2014       2015      2016      2017
# MONTH
# 1           77009.00  116158.04  222397.00  190142.00  146459.95  120307.0  103761.0
# 2          110686.00   29037.00   66187.00   80309.00   84614.00  126743.0       NaN
# 3          133894.00   56395.00   72425.00   67966.00   34651.10   17636.0  127201.0
# 4           48509.00   34795.00   15334.00    4545.00  107217.00  160176.0   33361.0
# 5           60323.00   71875.00   37707.00   41854.00   31380.00   26374.0   33361.0
# 6           26017.00   46648.00        NaN   19937.00   55935.00   41612.0       NaN
# 7           22183.00   26721.00   37221.00    6030.00   42374.00   38394.0       NaN
# 8           42165.00   70519.00   73000.00   59934.00   54209.00  126951.0       NaN
# 9           79187.00   77520.41   46711.00  112548.00   83822.00   66732.0       NaN
# 10         126503.50   96569.00  192896.00  238018.70  335518.20  314185.0       NaN
# 11         194246.00  263324.00  191947.60  349983.76  293990.30  161820.7       NaN
# 12         205377.03   48927.00   24500.15  150201.00  285491.00  409411.0       NaN
#
# ----- Pesos Bruto Total del grupo E ------
#
#       PESOBRUTOTOTAL
# YEAR            2012       2013      2014      2015     2016      2017
# MONTH
# 1           56686.00   78086.00  62961.00  60230.00  24040.0   17669.0
# 2           30834.00  127285.51  58179.00  21691.00   9390.0    8380.0
# 3           22649.00  111796.60  84101.80  31118.00  39239.0  131372.0
# 4          120178.00   79589.20  65428.00  55179.00  20612.0   47462.0
# 5           38801.76   52038.00  68972.00  25726.00  12803.0   47462.0
# 6          104570.00  110963.20  25003.00  43100.00  15751.0       NaN
# 7          100511.00   80029.00  22109.00  71004.48   5444.0       NaN
# 8          128427.42   76294.00  35640.36  17770.00  75422.0       NaN
# 9           31816.64   41332.00  65284.00  58858.00  12884.0       NaN
# 10          54266.60   55975.00  56790.00  24292.20  29363.0       NaN
# 11         124986.60   53511.60  30445.00  49025.00  44528.0       NaN
# 12          76448.52  127810.00  72300.00  22502.00  49195.0       NaN
# ----- Valor FOB Total del grupo A ------
#
#       TOTALVALORFOB
# YEAR           2011         2012         2013         2014        2015        2016        2017
# MONTH
# 1         109359.26    798348.93    618258.48    319458.90   333557.96   594066.49  1255157.47
# 2         214696.82    218256.73    130573.70     11697.61   211450.80   111724.29   206508.91
# 3         542863.92    980235.75    818131.23    977884.51   889103.46   925634.59   969346.76
# 4        1057427.99   2192950.12   2193185.68    850554.14   272090.20   601686.32   427440.70
# 5        1095211.53   1748003.46    654966.16   3714395.79  1219748.41  2568010.35   427440.70
# 6        2451311.93   2318499.62   4248276.02    404701.94  1323523.51   165790.09         NaN
# 7        2769774.63    303106.31   1163805.60   3422135.52   995059.94   141999.52         NaN
# 8       19404673.17   5562626.75   8140748.90   7279405.01  2170047.78  3763064.36         NaN
# 9       19750238.81  12776447.22  16182207.46   8840721.92  6081746.62  6144837.14         NaN
# 10      14027748.05  17524114.96   9709876.82  11071556.83  8785735.18  7423052.15         NaN
# 11       3695169.07   6946169.09   2229498.47   2108276.04  3646048.69  3276061.71         NaN
# 12       2710514.72   1445530.81    862583.19    791903.42  1434873.06  2571880.40         NaN
#
# ----- Valor FOB Total del grupo B ------
#
#       TOTALVALORFOB
# YEAR           2011       2012       2013      2014       2015       2016
# MONTH
# 1          29353.51        NaN        NaN       NaN        NaN        NaN
# 2         467485.45        NaN        NaN       NaN        NaN        NaN
# 3         193241.54        NaN        NaN       NaN        NaN   62296.36
# 4        1693149.54   20650.00        NaN       NaN        NaN        NaN
# 5        4470684.73        NaN   37900.50  20207.94        NaN   18861.04
# 6        2840655.14  202821.98  101981.88  98761.23  165077.21  113433.02
# 7        1162479.83    3991.48  444462.64       NaN    2212.83        NaN
# 8         104882.68   11692.31    4200.00       NaN        NaN        NaN
# 9         844997.13        NaN        NaN       NaN        NaN        NaN
# 10          9802.75        NaN        NaN       NaN        NaN        NaN
# 11         11285.09        NaN        NaN       NaN        NaN        NaN
# 12        890300.00        NaN        NaN       NaN        NaN        NaN
#
# ----- Valor FOB Total del grupo C ------
#
#       TOTALVALORFOB
# YEAR           2012       2013       2014      2015        2016        2017
# MONTH
# 1           4997.00        NaN   36851.50       NaN         NaN  1139600.00
# 2          34514.28  148512.85   41466.56   6209.80         NaN         NaN
# 3         299534.03        NaN   50229.59  95358.90         NaN     7200.66
# 4          92545.76  128376.10   93700.37  47803.77     2960.75    35668.65
# 5          55138.54   90820.52  223325.44  97834.72    17250.10    35668.65
# 6         123872.63  107611.04  103527.42  76660.16    44673.52         NaN
# 7          28804.10   47817.23   41055.07  38650.00  1012840.96         NaN
# 8               NaN        NaN   42483.67       NaN  2033864.04         NaN
# 9           1950.50        NaN   13486.77  16091.37   736581.96         NaN
# 10         25426.02   15939.92   17505.43       NaN    46214.23         NaN
# 11              NaN        NaN        NaN       NaN    48626.75         NaN
# 12         57174.31        NaN        NaN    605.00  1302531.06         NaN
#
# ----- Valor FOB Total del grupo D ------
#
#       TOTALVALORFOB
# YEAR           2011        2012        2013        2014        2015        2016       2017
# MONTH
# 1         495058.73   592148.84  1214541.01  1118389.72  2159014.24  1627807.50  895156.12
# 2         655032.94   178936.59   424762.77   472413.25   870156.00  1069653.61        NaN
# 3         672511.40   253423.45   319345.41   329906.56   437619.64   157714.73  885830.89
# 4         294389.95   219299.60    47194.19    57021.89  1102698.00  1229919.01  325616.82
# 5         323737.23   348658.30   254649.00   323006.91   260109.74   201734.12  325616.82
# 6         106191.33   269010.05         NaN   226201.20   443142.46   378498.00        NaN
# 7         156445.13   338746.00   263030.30    13651.50   520688.60   390165.00        NaN
# 8         354461.01   492922.55   852717.10   815490.60   436793.00  1263188.40        NaN
# 9         899755.14   820413.61   526141.43  1577116.20   867747.00   664124.30        NaN
# 10       1090380.43   893690.49  1987743.65  3475841.17  3581616.25  3457573.79        NaN
# 11       1154075.97  1505851.75  1089925.76  6354875.86  3565977.23  2080879.37        NaN
# 12       1153416.65   399839.61   191554.63  2372118.35  4785809.03  5395986.63        NaN
#
# ----- Valor FOB Total del grupo E ------
#
#       TOTALVALORFOB
# YEAR           2012       2013       2014       2015       2016       2017
# MONTH
# 1         202834.82  274287.35  274556.06  334331.84  110180.00  100986.75
# 2          98711.48  417287.30  228651.75  112933.00   71717.00   29467.60
# 3          70737.27  367861.83  316641.00  128063.06  130766.44  487187.85
# 4         411310.63  262019.00  250291.12  257318.50  153141.40  231492.16
# 5         188934.75  222193.79  303065.48   96426.35   61953.06  231492.16
# 6         359180.42  392417.95  138806.62  217882.13  118495.50        NaN
# 7         438932.74  304631.50  101923.35  331547.28   54687.00        NaN
# 8         496845.25  361723.84  261757.72  113269.32  604353.51        NaN
# 9         198133.37  177115.30  412447.46  276025.16   83083.18        NaN
# 10        258738.73  328276.15  424518.03  264047.90  256918.90        NaN
# 11        413550.12  208913.48  447312.63  310016.67  270232.66        NaN
# 12        261519.49  491140.10  440706.55  363204.00  423311.80        NaN

# %% [markdown]
# ### Cuanto importamos y exportamos de A,B,C,D y E (de cada grupo FOB, CIF, BULTOS, PESO TOTAL ) por año?

# %%
filename_export = "data" + os.sep + "export" + os.sep + "all_export_with_group.txt"
filename_import = "data" + os.sep + "import" + os.sep + "all_import_with_group.txt"

usecols_export =  ["YEAR", "TOTALBULTOS", "PESOBRUTOTOTAL", "TOTALVALORFOB", "VALORCIF", "GROUP"]
usecols_import =  ["YEAR", "FOB", "CIF", "CANT_BUL1", "TOT_PESO", "GROUP"]

data_import = pd.read_csv(filename_import, decimal=',',
                   sep=";", encoding="latin1", quoting=csv.QUOTE_NONE,
                   usecols = usecols_import)

data_export = pd.read_csv(filename_export, decimal=',',
                          sep=";", encoding="latin1", quoting=csv.QUOTE_NONE,
                          usecols = usecols_export)
# concatenate data

data_import["TYPE"] = "Import"
data_export["TYPE"] = "Export"

data_import.columns = ['BULTOS', 'PESO', 'FOB', 'CIF', 'YEAR', "GROUP", 'TYPE']

data_export.columns = ['FOB', 'PESO', 'CIF', 'BULTOS', 'YEAR', "GROUP", 'TYPE']

final_data = pd.concat([data_import, data_export])

for element, text in [("BULTOS", "Cantidad de Bultos"),
                      ("PESO"  , "Pesos Bruto Total" ),
                      ("FOB"   , "Valor FOB Total"   ),
                      ("CIF"   , "Valor CIF"         )]:
    
    fig, axes_year_share_y = plt.subplots(5, sharex=True, sharey=True)
    fig, axes_year = plt.subplots(5, sharex=True)

    i = 0
    
    tables = []

    for group in ["A", "B", "C", "D", "E"]:
        
        new_data = final_data[["YEAR", "GROUP", "TYPE", element]]
        
        new_data = new_data[new_data["GROUP"] == group]
        
        new_data_grouper = new_data.groupby(['YEAR', "TYPE"]).sum()
        
        for year in range(2011, 2018):
            if year not in new_data_grouper.index:
                new_data.loc[new_data.shape[0]] = [year, group, "Export", 0]
                new_data.loc[new_data.shape[0]] = [year, group, "Import", 0]
                
                new_data_grouper = new_data.groupby(['YEAR', "TYPE"]).sum()
                
        plot = new_data_grouper.unstack().plot(kind='bar',
                                               ax=axes_year_share_y[i],
                                               figsize=(15, 20))

        plot.set_title(text + " grupo " + group + " por año. Comparten Eje y")
        plot.set_xlabel("Añox")
        plot.set_ylabel(text)
        plot.set_xticklabels(("2011", "2012", "2013", "2014", "2015", "2016", "2017"), rotation="horizontal")
        plot.legend(["Export","Import"], loc=9,ncol=7)
        
        
        plot = new_data_grouper.unstack().plot(kind='bar',
                                               ax=axes_year[i],
                                               figsize=(15, 20))

        plot.set_title(text + " grupo " + group + " por año")
        plot.set_xlabel("Añox")
        plot.set_ylabel(text)
        plot.set_xticklabels(("2011", "2012", "2013", "2014", "2015", "2016", "2017"), rotation="horizontal")
        plot.legend(["Export","Import"], loc=9,ncol=7)
        
        i+=1
                
        tables.append(new_data_grouper.unstack().to_string())
        
    plt.show()
    
    for table, group in zip(tables, ["A", "B", "C", "D", "E"]):
        print("----- {} del grupo {} ------\n\n{}\n".format(text, group, table))
# Out:
# ----- Cantidad de Bultos del grupo A ------
#
#           BULTOS
# TYPE      Export       Import
# YEAR
# 2011  1549874.92  17309724.31
# 2012  1437361.79  13469915.13
# 2013  1553499.56  14220578.39
# 2014  1325736.25  18663180.65
# 2015   783076.93  18205923.90
# 2016   745586.27  18341156.64
# 2017    48970.35  12052815.57
#
# ----- Cantidad de Bultos del grupo B ------
#
#      BULTOS
# TYPE Export      Import
# YEAR
# 2011    0.0  2566912.47
# 2012    0.0  2882652.77
# 2013    0.0  2263829.19
# 2014    0.0  4376466.61
# 2015    0.0  2075668.56
# 2016    0.0  2036521.24
# 2017    NaN   698323.90
#
# ----- Cantidad de Bultos del grupo C ------
#
#         BULTOS
# TYPE    Export      Import
# YEAR
# 2011      0.00        0.00
# 2012      0.00   593060.81
# 2013      0.00   418141.30
# 2014  24665.12   456761.39
# 2015  13638.10   577554.59
# 2016  12735.00  1166512.70
# 2017      0.00   372551.85
#
# ----- Cantidad de Bultos del grupo D ------
#
#            BULTOS
# TYPE       Export        Import
# YEAR
# 2011   7437910.00  2.372314e+07
# 2012   6840894.48  3.824304e+07
# 2013   8519996.46  4.428675e+07
# 2014  19317204.54  5.197818e+07
# 2015  20821927.73  5.189724e+07
# 2016  20195854.00  4.985100e+07
# 2017   3031090.21  2.150890e+07
#
# ----- Cantidad de Bultos del grupo E ------
#
#           BULTOS
# TYPE      Export      Import
# YEAR
# 2011        0.00        0.00
# 2012  2072999.78  3123187.16
# 2013  1165041.70  2510994.75
# 2014  2570184.98   645557.27
# 2015  2579599.67   969346.51
# 2016  2174249.09  1449122.34
# 2017   868420.00   330664.71
# ----- Pesos Bruto Total del grupo A ------
#
#              PESO
# TYPE       Export      Import
# YEAR
# 2011  22769250.78  5949038.63
# 2012  19978840.50  5393486.07
# 2013  19025808.70  5310456.20
# 2014  16816417.90  6751091.10
# 2015  13566733.44  8211330.65
# 2016  13393482.39  9189338.60
# 2017   1041378.18  6229683.57
#
# ----- Pesos Bruto Total del grupo B ------
#
#             PESO
# TYPE      Export      Import
# YEAR
# 2011  1895654.81  1651199.45
# 2012    19277.00  1930892.70
# 2013   403142.00  1515905.56
# 2014     1335.00  2518880.11
# 2015   268350.00  1247608.87
# 2016    75578.00   921746.22
# 2017         NaN   364364.35
#
# ----- Pesos Bruto Total del grupo C ------
#
#            PESO
# TYPE     Export      Import
# YEAR
# 2011       0.00        0.00
# 2012   22446.77   155309.00
# 2013   20602.08    88525.92
# 2014   24551.49    96178.21
# 2015   51773.84   720494.06
# 2016  187308.90  1470658.75
# 2017   56943.00   854532.97
#
# ----- Pesos Bruto Total del grupo D ------
#
#             PESO
# TYPE      Export       Import
# YEAR
# 2011  1126099.53   9194225.68
# 2012   938488.45  12697913.29
# 2013   980325.75  14133215.59
# 2014  1321468.46  16674565.94
# 2015  1555661.55  16126904.43
# 2016  1610341.70  18129980.73
# 2017   297684.00   8248503.35
#
# ----- Pesos Bruto Total del grupo E ------
#
#            PESO
# TYPE     Export     Import
# YEAR
# 2011       0.00       0.00
# 2012  890175.54  474493.11
# 2013  994710.11  433445.89
# 2014  647213.16  137285.56
# 2015  480495.68  237387.78
# 2016  338671.00  435810.04
# 2017  252345.00   89176.24
# ----- Valor FOB Total del grupo A ------
#
#          FOB
# TYPE  Export       Import
# YEAR
# 2011  3503.0  18909243.40
# 2012  2761.0  14824201.89
# 2013  1994.0  15635266.45
# 2014  1885.0  20389765.19
# 2015  1634.0  19646835.20
# 2016  1712.0  19736597.77
# 2017   526.0  12830797.94
#
# ----- Valor FOB Total del grupo B ------
#
#          FOB
# TYPE  Export      Import
# YEAR
# 2011  4848.0  3489740.30
# 2012    80.0  3795678.43
# 2013    63.0  3012233.85
# 2014    32.0  5265446.49
# 2015    31.0  2664202.53
# 2016    46.0  2431777.31
# 2017     NaN   898469.48
#
# ----- Valor FOB Total del grupo C ------
#
#          FOB
# TYPE  Export      Import
# YEAR
# 2011     0.0        0.00
# 2012  2265.0   733279.54
# 2013  1598.0   552458.17
# 2014  1651.0   634736.20
# 2015   823.0   749487.16
# 2016  1342.0  1462245.95
# 2017   192.0   468637.10
#
# ----- Valor FOB Total del grupo D ------
#
#            FOB
# TYPE    Export       Import
# YEAR
# 2011  179995.0  33899965.00
# 2012  158126.0  52058971.07
# 2013  183725.0  59264660.17
# 2014  259021.0  64656404.18
# 2015  313119.0  62987933.19
# 2016  344793.0  61313283.32
# 2017   54626.0  26247041.07
#
# ----- Valor FOB Total del grupo E ------
#
#           FOB
# TYPE   Export      Import
# YEAR
# 2011      0.0        0.00
# 2012  15293.0  3388135.52
# 2013  18391.0  2776571.17
# 2014  24853.0   730921.96
# 2015  30451.0  1071503.15
# 2016  30028.0  1585320.06
# 2017   7026.0   366394.87
# ----- Valor CIF del grupo A ------
#
#               CIF
# TYPE       Export  Import
# YEAR
# 2011  67828989.90  3692.0
# 2012  52814289.75  1986.0
# 2013  46952111.71  2109.0
# 2014  39792691.63  2384.0
# 2015  27362985.61  1655.0
# 2016  28287807.41  1061.0
# 2017   3285894.54   384.0
#
# ----- Valor CIF del grupo B ------
#
#               CIF
# TYPE       Export  Import
# YEAR
# 2011  12718317.39  9004.0
# 2012    239155.77  3336.0
# 2013    588545.02  6087.0
# 2014    118969.17  4854.0
# 2015    167290.04  5135.0
# 2016    194590.42  2275.0
# 2017          NaN  1256.0
#
# ----- Valor CIF del grupo C ------
#
#              CIF
# TYPE      Export  Import
# YEAR
# 2011        0.00     0.0
# 2012   723957.17  1450.0
# 2013   539077.66  1198.0
# 2014   663631.82  1582.0
# 2015   379213.72   549.0
# 2016  5245543.37  3044.0
# 2017  1218137.96   278.0
#
# ----- Valor CIF del grupo D ------
#
#               CIF
# TYPE       Export    Import
# YEAR
# 2011   7355455.91  260048.0
# 2012   6312940.84  332190.0
# 2013   7171605.25  459997.0
# 2014  17136033.21  412091.0
# 2015  19031371.19  322211.0
# 2016  17917244.46  345822.0
# 2017   2432220.65  156238.0
#
# ----- Valor CIF del grupo E ------
#
#              CIF
# TYPE      Export  Import
# YEAR
# 2011        0.00     0.0
# 2012  3399429.07   532.0
# 2013  3807867.59   168.0
# 2014  3600677.77   443.0
# 2015  2805065.21  1025.0
# 2016  2338840.45  1926.0
# 2017  1080626.52   544.0
